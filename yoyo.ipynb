# %%
import pandas as pd

# %%
flights = pd.read_csv("new_flights.csv")

# %%
flights
# Out:
#         YEAR  MONTH  DAY AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0       2015      5   26      WN            STL                 DAL
# 1       2015      2    6      WN            BUR                 OAK
# 2       2015      1    3      AS            SAN                 SEA
# 3       2015     12    6      EV            EWR                 DCA
# 4       2015      2   28      WN            MHT                 TPA
# ...      ...    ...  ...     ...            ...                 ...
# 212418  2015      1    4      WN            BNA                 LGA
# 212419  2015      2   12      UA            ORD                 BWI
# 212420  2015      2   27      UA            SEA                 ORD
# 212421  2015      9   15      WN            SJC                 PDX
# 212422  2015      5   21      WN            SAN                 ABQ
#
#         SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY  \
# 0                       810            1043              153
# ...

# %%
flights_data = pd.read_csv("new_flight_data.csv")
# Out:
# C:\Users\amanj\AppData\Local\Temp\ipykernel_1828\3721230366.py:1: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   flights_data = pd.read_csv("new_flight_data.csv")

# %%
flights_data
# Out:
#         ORIGIN_AIRPORT DESTINATION_AIRPORT
# 0                  ANC                 SEA
# 1                  LAX                 PBI
# 2                  SFO                 CLT
# 3                  LAX                 MIA
# 4                  SEA                 ANC
# ...                ...                 ...
# 5819074            LAX                 BOS
# 5819075            JFK                 PSE
# 5819076            JFK                 SJU
# 5819077            MCO                 SJU
# 5819078            JFK                 BQN
#
# [5819079 rows x 2 columns]

# %%
flights_data = flights_data.sample(frac=0.2, random_state=42)

# %%
flights_data
# Out:
#         ORIGIN_AIRPORT DESTINATION_AIRPORT
# 1508570            FWA                 DTW
# 363270             LAS                 SEA
# 3003945            OAK                 SEA
# 2291425            STL                 DAL
# 2973084            IAH                 HNL
# ...                ...                 ...
# 870505             SEA                 ORD
# 1010803            LAS                 ATL
# 4149295            SJC                 PDX
# 2529800            ORD                 EVV
# 2223205            SAN                 ABQ
#
# [1163816 rows x 2 columns]

# %%
new_df = flights_data[['ORIGIN_AIRPORT', 'DESTINATION_AIRPORT']].head(212423)

new_df.to_csv('idea.csv', index=False)
